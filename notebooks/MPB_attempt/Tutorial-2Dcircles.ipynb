# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import matplotlib.pyplot as plt

import sys
sys.path.append('../../lib')
from meep_nb import *

import math
import meep as mp
from meep import mpb
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
num_bands = 8
k_points = [mp.Vector3(),          # Gamma
            mp.Vector3(0.5),       # X
            mp.Vector3(0.5, 0.5),  # M
            mp.Vector3()]          # Gamma
k_points = mp.interpolate(4, k_points)

# %%
geometry = [mp.Block(mp.Vector3(.5, .5), center=mp.Vector3(0, 0), material=mp.Medium(epsilon=12))] # height is infinite
geometry_lattice = mp.Lattice(size=mp.Vector3(1, 1))
resolution = 32

# %%
ms = mpb.ModeSolver(num_bands=num_bands,
                    k_points=k_points,
                    geometry=geometry,
                    geometry_lattice=geometry_lattice,
                    resolution=resolution)

# %%
# Run it
ms.run_te(mpb.fix_hfield_phase)
# ms.run_tm(mpb.fix_efield_phase)
# ms.run_te(mpb.output_at_kpoint(mp.Vector3(0.5), mpb.output_hfield_z, mpb.output_dpwr))
# Out:
# Initializing eigensolver data
# Computing 8 bands with 1e-07 tolerance
# 16 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.1, 0.0, 0.0>
#   Vector3<0.2, 0.0, 0.0>
#   Vector3<0.30000000000000004, 0.0, 0.0>
#   Vector3<0.4, 0.0, 0.0>
#   Vector3<0.5, 0.0, 0.0>
#   Vector3<0.5, 0.1, 0.0>
#   Vector3<0.5, 0.2, 0.0>
#   Vector3<0.5, 0.30000000000000004, 0.0>
#   Vector3<0.5, 0.4, 0.0>
#   Vector3<0.5, 0.5, 0.0>
#   Vector3<0.4, 0.4, 0.0>
#   Vector3<0.3, 0.3, 0.0>
#   Vector3<0.19999999999999996, 0.19999999999999996, 0.0>
#   Vector3<0.09999999999999998, 0.09999999999999998, 0.0>
#   Vector3<0.0, 0.0, 0.0>
# elapsed time for initialization: 0.002536296844482422
# elapsed time for k point: 0.06227302551269531
# elapsed time for k point: 0.15146398544311523
# elapsed time for k point: 0.02811121940612793
# elapsed time for k point: 0.031163930892944336
# elapsed time for k point: 0.0330660343170166
# elapsed time for k point: 0.0329890251159668
# elapsed time for k point: 0.028197050094604492
# elapsed time for k point: 0.02212810516357422
# elapsed time for k point: 0.022736072540283203
# elapsed time for k point: 0.02225780487060547
# elapsed time for k point: 0.022043943405151367
# elapsed time for k point: 0.04024100303649902
# elapsed time for k point: 0.0247342586517334
# elapsed time for k point: 0.02439117431640625
# elapsed time for k point: 0.02611708641052246
# elapsed time for k point: 0.03446602821350098
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.38069331121144134 at Vector3<0.5, 0.5, 0.0>
# Band 2 range: 0.35478204227282994 at Vector3<0.5, 0.0, 0.0> to 0.4921678674949589 at Vector3<0.5, 0.5, 0.0>
# Band 3 range: 0.492168226120356 at Vector3<0.5, 0.5, 0.0> to 0.5966670294529987 at Vector3<0.0, 0.0, 0.0>
# Band 4 range: 0.5966670483737648 at Vector3<0.0, 0.0, 0.0> to 0.647117457664289 at Vector3<0.5, 0.2, 0.0>
# Band 5 range: 0.6506701991656305 at Vector3<0.5, 0.2, 0.0> to 0.709374733532097 at Vector3<0.5, 0.5, 0.0>
# Band 6 range: 0.7093749543008653 at Vector3<0.5, 0.5, 0.0> to 0.7777360988076428 at Vector3<0.0, 0.0, 0.0>
# Band 7 range: 0.8118259833726967 at Vector3<0.5, 0.5, 0.0> to 0.890183630407342 at Vector3<0.0, 0.0, 0.0>
# Band 8 range: 0.8459296148130169 at Vector3<0.5, 0.5, 0.0> to 0.9270334667438711 at Vector3<0.5, 0.0, 0.0>
# Gap from band 2 (0.4921678674949589) to band 3 (0.492168226120356), 7.286645271411305e-05%
# Gap from band 3 (0.5966670294529987) to band 4 (0.5966670483737648), 3.171076151701353e-06%
# Gap from band 4 (0.647117457664289) to band 5 (0.6506701991656305), 0.5475073649598059%
# Gap from band 5 (0.709374733532097) to band 6 (0.7093749543008653), 3.1121595325768373e-05%
# Gap from band 6 (0.7777360988076428) to band 7 (0.8118259833726967), 4.2892171305815445%
# total elapsed time for run: 0.6273889541625977
# done

# %%
# Visualize index structure
converted_eps = show_geometry(ms)

# %%
# ef = ms.get_efield(which_band=2)
# plt.imshow(np.real(ef)[:,:,0,2], cmap='seismic')
# ef
md = mpb.MPBData(rectify=True, periods=3, resolution=32)
# eps = ms.get_hfield(which_band=2)
# eps_data = md.convert(eps)  # make aspect ratios right

fi, ax = plt.subplots(nrows=num_bands, ncols=3*2, figsize=(15,3*num_bands))
for iBand in range(num_bands):
    axRow = ax[iBand]
    for iDim in range(6):
        plt.sca(axRow[iDim])
        if iDim < 3:
            eps = ms.get_efield(which_band=iBand, bloch_phase=False)
        else:
            eps = ms.get_hfield(which_band=iBand, bloch_phase=False)
        eps_data = md.convert(eps)
        scalar_data = np.real(eps_data[:, :, iDim % 3])
        
        plt.contour(converted_eps.T, cmap='binary', linewidths=1)
        vrange = max(abs(np.max(scalar_data)), abs(np.min(scalar_data)))
        plt.imshow(scalar_data.transpose()[::-1], interpolation='spline36', cmap='RdBu_r',
                   alpha=0.9, vmin=-vrange, vmax=vrange)
        plt.axis('off')
        plt.title('iBand={}, axis={}'.format(iBand, ['x', 'y', 'z'][iDim%3]))
